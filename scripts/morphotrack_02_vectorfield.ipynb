# %%
import numpy as np
from skimage import data, io
from skimage.filters import threshold_otsu
from skimage.morphology import skeletonize
import os
from matplotlib import pyplot as plt
import pandas as pd
import napari
import tifffile
from scipy import spatial
import pickle

from sklearn.preprocessing import normalize, PolynomialFeatures
from sklearn import linear_model

from threadpoolctl import threadpool_limits
import ray
# Out:
# /home/tmurakami/app/miniconda3/envs/segment/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
io_directory = '/mnt/ampa_data01/tmurakami/220806_visual_01_R01/morphotrack'

# %%
# get binary data for blood vesssel
# mask_labkit = io.imread(os.path.join(io_directory,'vessel.tif'))
mask = io.imread(os.path.join(io_directory,'vessel_labkit.tif'))==1# mask_labkit==1
dim = mask.ndim
shape = mask.shape

# skeletonization for vector analysis
skeleton = skeletonize(mask)

# %%
viewer = napari.Viewer()
viewer.add_image(mask, contrast_limits=[0,2], rgb=False, name='mask', colormap='magenta', blending='additive')
viewer.add_image(skeleton, contrast_limits=[0,2], rgb=False, name='skeleton', colormap='green', blending='additive')
# Out:
# <Image layer 'skeleton' at 0x7f5764154f70>

# %%
# mask_meninge = 1 - tifffile.imread(os.path.join(io_directory,'meninge.tif'))
# Prepare mask. This time, use mask prepared with ClearMap.
# mask = np.load(os.path.join(io_directory,'binary_final.npy'))#np.load('/scratch2/Share/tmurakami/220121_human_sma_5mm_1st/vessel/binary_final.npy')
# Prepare skeleton. Use the skeleton prepared with ClearMap.
# skeleton = np.load(os.path.join(io_directory,'skeleton.npy'))

# %%
# mask = mask * mask_meninge
mask_1d = mask.flatten()

# Extract the vectors and positions using mask.
points_position_array = np.array(np.where(mask)).T
points_position = points_position_array.tolist()

# %%
# manually design your guide vector
# To Do: automation of the vector detection.
guide_coordinate1 = np.array([195.,289.,352.])
guide_coordinate2 = np.array([113.,331.,284.])
guide_vector = guide_coordinate2 - guide_coordinate1
guide_vector = guide_vector / np.linalg.norm(guide_vector)

# %%
# skeleton = skeleton * mask_meninge
skeleton_1d = skeleton.flatten()

# Extract the position of the skeleton for the vector field analysis.
skeleton_position_array = np.array(np.where(skeleton)).T
skeleton_position = skeleton_position_array.tolist()

# %%
def align_vector_sign(vectors, guide_vector=None):
    '''
    Align the sign of the vector by refering a guide vector. If the dot product of the vector and the guide vector is negative, the sign of vector is flipped.
    Highly encourage to make a guide vector before align sign.
    '''
    if (guide_vector is None):
        guide_vector = normalize(np.median(vectors,axis=0)[:,np.newaxis],axis=0).ravel()
    aligned_vectors = np.where(
        np.repeat(np.expand_dims(np.matmul(vectors, guide_vector) >= 0, axis=1), guide_vector.size, axis=1),
        vectors,
        -vectors
    )
    return aligned_vectors

# %%
# Vector field analysis on skeleton using neighbors.
kdtree = spatial.KDTree(skeleton_position_array)
k = 27 # Number of neighbors.
mean_skeleton_vectors = []

for point, point_position in enumerate(skeleton_position):
    # Extract vectors from k-nearest neighbors.
    d, neighbors = kdtree.query(point_position,k)
    neighbors = neighbors[d!=0]
    vectors_from_neighbors = normalize(skeleton_position_array[neighbors,:]-point_position,axis=1) # Normalize to equalize the weights
    mean_vector = np.mean(align_vector_sign(vectors_from_neighbors,guide_vector),axis=0) # Use arithmetic mean.
    mean_vector = normalize(mean_vector[:,np.newaxis],axis=0).ravel()
    mean_skeleton_vectors.append(mean_vector)
mean_skeleton_vectors = np.array(mean_skeleton_vectors)

# %%
# Expansion of vector field to binarized image.
kdtree = spatial.KDTree(skeleton_position_array)
k = 1 # Number of neighbors in skeleton.
point_vectors = []

for point, point_position in enumerate(points_position):
    _, neighbors = kdtree.query(point_position,k)
    neighbor_vector = mean_skeleton_vectors[neighbors]
#     if k > 1:
#         mean_neighbor_vectors =np.mean(neighbor_vector,axis=0)
#         neighbor_vector = normalize(mean_neighbor_vectors[:,np.newaxis],axis=0).ravel()
    point_vectors.append(neighbor_vector)
point_vectors = np.array(point_vectors)

# %%
'''Start denoising'''
# Out:
# 'Start denoising'

# %%
@ray.remote
def get_neighbor_vectors(point_position, kdtree, vectors, radius):
    if not isinstance(point_position, np.ndarray):
        point_position = np.array(point_position)
    neighbors = kdtree.query_ball_point(point_position,radius)
    neighbor_vectors = vectors[neighbors,:]
    return neighbor_vectors

@ray.remote
def get_median_vector(vectors):
    # Ideally, the medoid vector should be calculated, but it is resource demanding. Instead, calculate the median in each dimension and normalize to a unit vector.
    """
    vectors: ndarray
    """
    median_vector = normalize(np.median(vectors,axis=0)[:,np.newaxis],axis=0).ravel()
    return median_vector

@ray.remote
def get_point_vector(point, vectors):
    return vectors[point]

@ray.remote
def single_thread_align_vector_sign(vectors, guide_vector):
    '''
    Align the sign of the vector by refering a guide vector. If the dot product of the vector and the guide vector is negative, the sign of vector is flipped.
    '''
    with threadpool_limits(limits=1, user_api='blas'):
        aligned_vectors = np.where(
            np.repeat(np.expand_dims(np.matmul(vectors, guide_vector) >= 0, axis=1), guide_vector.size, axis=1),
            vectors,
            -vectors
        )
    return aligned_vectors

@ray.remote
def select_point_in_dot_product_space(point_vector, neighbor_vectors, median_vector, k=10):
    with threadpool_limits(limits=1, user_api='blas'):
        # Calculate the dot product
        dot_product = np.matmul(neighbor_vectors, median_vector) # This is done in parallel otherwise stated.
        dot_product_of_point = np.matmul(point_vector,median_vector)
    if k>dot_product.size:
        selection = False
    else:
        # Find k neighbors in dot product space
        dot_product_neighbors = dot_product[np.argsort(np.abs(dot_product-dot_product_of_point))][0:k]
        # Calculate the null density if the density is even distribution.
        null_density = dot_product.size*(dot_product_neighbors.max()-dot_product_neighbors.min())
        selection = (k>null_density)
    # Second selection using otsu thresholding
    if selection:
        thresh = threshold_otsu(dot_product)
        selection = (dot_product_of_point>thresh)
    return selection

@ray.remote
def dot_product_vectors(vector1, vector2):
    with threadpool_limits(limits=1, user_api='blas'):
        dot_product = np.matmul(vector1, vector2)
    return dot_product

# %%
# %%time
kdtree = spatial.KDTree(points_position_array)
radius = 42 # pixel unit. 500 / voxel micrometer works well. diameter in real scale: 2 * radius * voxelsize. 
k = 10 # Number of neighbor in dot product space. Note this is not a number of neighbor in 3D image space.
keeping = []
# dot_p = []

kdtree_id = ray.put(kdtree)
vectors_id = ray.put(point_vectors)

for point, point_position in enumerate(points_position):
    point_vector = get_point_vector.remote(point, vectors_id)
    # Get vectors in neighbor points.
    neighbor_vectors = get_neighbor_vectors.remote(point_position, kdtree_id, vectors_id, radius)
    # Make representitive vector
    median_vector = get_median_vector.remote(neighbor_vectors)
    neighbor_vectors = single_thread_align_vector_sign.remote(neighbor_vectors, median_vector) # Fix the sign of vectors.

    keeping.append(select_point_in_dot_product_space.remote(point_vector, neighbor_vectors, median_vector, k))
    # dot_p.append(dot_product_vectors.remote(point_vector,median_vector))
# Out:
# (get_point_vector pid=1825940)
# (get_point_vector pid=1825953)
# (get_point_vector pid=1825945)
# (get_median_vector pid=1825916)
# (get_point_vector pid=1825940)
# (get_point_vector pid=1825951)
# (get_median_vector pid=1825969)
# (get_median_vector pid=1825927)
# (get_neighbor_vectors pid=1825900)
# (get_point_vector pid=1825984)
# (get_point_vector pid=1825935)
# (get_point_vector pid=1825955)
# (get_point_vector pid=1825940)
# (get_median_vector pid=1825976)
# (get_median_vector pid=1825843)
# (get_neighbor_vectors pid=1825940)
# (get_point_vector pid=1825955)
# (get_median_vector pid=1825906)
# (get_point_vector pid=1825930)
# (get_neighbor_vectors pid=1825924)
# (select_point_in_dot_product_space pid=1825943)
# (select_point_in_dot_product_space pid=1825926)
# (select_point_in_dot_product_space pid=1825953)
# (get_median_vector pid=1825895)
# (get_median_vector pid=1825896)
# (get_point_vector pid=1825968)
# (get_point_vector pid=1825956)
# (select_point_in_dot_product_space pid=1825956)
# (get_point_vector pid=1825912)
# (select_point_in_dot_product_space pid=1825980)
# (get_point_vector pid=1825907)
# (get_neighbor_vectors pid=1825987)
# (get_median_vector pid=1825933)
# (get_point_vector pid=1825982)
# (single_thread_align_vector_sign pid=1825961)
# (get_median_vector pid=1825927)
# (get_point_vector pid=1825951)
# (get_point_vector pid=1825911)
# (get_neighbor_vectors pid=1825904)
# (get_point_vector pid=1825916)
# (single_thread_align_vector_sign pid=1825916)
# (single_thread_align_vector_sign pid=1825916)
# (select_point_in_dot_product_space pid=1827472)
# (get_neighbor_vectors pid=1825911)
# (get_median_vector pid=1825935)
# (get_median_vector pid=1825935)
# (get_neighbor_vectors pid=1825972)
# (get_point_vector pid=1825951)
# (get_median_vector pid=1825909)
# (single_thread_align_vector_sign pid=1827472)
# (get_neighbor_vectors pid=1825978)
# (get_median_vector pid=1825895)
# (get_point_vector pid=1825969)
# (get_median_vector pid=1827497)
# (get_point_vector pid=1825964)
# (get_point_vector pid=1825926)
# (get_median_vector pid=1825949)
# (get_point_vector pid=1825933)
# (get_neighbor_vectors pid=1825946)
# (get_point_vector pid=1825946)
# (select_point_in_dot_product_space pid=1825894)
# (get_median_vector pid=1825897)
# (get_median_vector pid=1825946)
# (get_point_vector pid=1825896)
# (single_thread_align_vector_sign pid=1825946)
# (get_neighbor_vectors pid=1825921)
# (get_neighbor_vectors pid=1825900)
# (single_thread_align_vector_sign pid=1825937)
# (get_point_vector pid=1825907)
# (get_neighbor_vectors pid=1825904)
# (get_point_vector pid=1825935)
# (get_point_vector pid=1825994)
# (select_point_in_dot_product_space pid=1825916)
# (get_neighbor_vectors pid=1825951)
# (get_point_vector pid=1825935)
# (get_point_vector pid=1825943)
# (select_point_in_dot_product_space pid=1825900)
# (get_point_vector pid=1825890)
# (get_neighbor_vectors pid=1825964)
# (get_median_vector pid=1825943)
# (get_point_vector pid=1825953)
# (select_point_in_dot_product_space pid=1825962)
# (get_median_vector pid=1825914)
# (get_point_vector pid=1827472)
# (get_neighbor_vectors pid=1825926)
# (single_thread_align_vector_sign pid=1825975)
# (select_point_in_dot_product_space pid=1825951)
# (get_median_vector pid=1825943)
# (get_neighbor_vectors pid=1825968)
# (get_point_vector pid=1825946)
# (get_point_vector pid=1825895)
# (single_thread_align_vector_sign pid=1825924)
# (get_median_vector pid=1825948)
# (select_point_in_dot_product_space pid=1825897)
# (single_thread_align_vector_sign pid=1825978)
# (select_point_in_dot_product_space pid=1825978)
# (get_median_vector pid=1825843)
# (get_point_vector pid=1825890)
# (select_point_in_dot_product_space pid=1825843)
# (get_neighbor_vectors pid=1825968)
# (get_point_vector pid=1825964)
# (get_point_vector pid=1825911)
# (get_point_vector pid=1825914)
# (get_neighbor_vectors pid=1825964)
# (single_thread_align_vector_sign pid=1825971)
# (get_point_vector pid=1825976)
# (single_thread_align_vector_sign pid=1825894)
# (single_thread_align_vector_sign pid=1825971)
# (get_point_vector pid=1825880)
# (single_thread_align_vector_sign pid=1825909)
# (single_thread_align_vector_sign pid=1825899)
# (select_point_in_dot_product_space pid=1830457)
# (select_point_in_dot_product_space pid=1825964)
# (single_thread_align_vector_sign pid=1825980)
# (get_point_vector pid=1825972)
# (get_point_vector pid=1825923)
# (get_point_vector pid=1825987)
# (get_point_vector pid=1825892)
# (get_neighbor_vectors pid=1825987)
# (get_median_vector pid=1825927)
# (get_neighbor_vectors pid=1825916)
# (get_point_vector pid=1825892)
# (get_point_vector pid=1825924)
# (get_median_vector pid=1825945)
# (get_neighbor_vectors pid=1825955)
# (get_point_vector pid=1830457)
# (get_neighbor_vectors pid=1825895)
# (get_point_vector pid=1825933)
# (select_point_in_dot_product_space pid=1825933)
# (single_thread_align_vector_sign pid=1825929)
# (get_point_vector pid=1825972)
# (get_median_vector pid=1825906)
# (get_point_vector pid=1825946)
# (get_neighbor_vectors pid=1825926)
# (get_point_vector pid=1825956)
# (get_point_vector pid=1825943)
# (get_point_vector pid=1826189)
# (get_point_vector pid=1825978)
# (get_point_vector pid=1825929)
# (get_point_vector pid=1825952)
# (select_point_in_dot_product_space pid=1825948)
# (get_median_vector pid=1825921)
# (select_point_in_dot_product_space pid=1825968)
# (get_median_vector pid=1825956)
# (get_median_vector pid=1825842)
# (get_median_vector pid=1825916)
# (get_point_vector pid=1825994)
# (single_thread_align_vector_sign pid=1825926)
# (get_point_vector pid=1825911)
# (select_point_in_dot_product_space pid=1830258)
# (get_point_vector pid=1825989)
# (single_thread_align_vector_sign pid=1825989)
# (get_median_vector pid=1825945)
# (get_point_vector pid=1825904)
# (single_thread_align_vector_sign pid=1825952)
# (get_point_vector pid=1825989)
# (get_point_vector pid=1825951)
# (select_point_in_dot_product_space pid=1830887)
# (get_point_vector pid=1825994)
# (get_point_vector pid=1825882)
# (get_point_vector pid=1825957)
# (get_point_vector pid=1825912)
# (get_neighbor_vectors pid=1825924)
# (get_point_vector pid=1825892)
# (single_thread_align_vector_sign pid=1825927)
# (single_thread_align_vector_sign pid=1825929)
# (get_point_vector pid=1825906)
# (get_median_vector pid=1825926)
# (get_neighbor_vectors pid=1825893)
# (get_point_vector pid=1825892)
# (get_point_vector pid=1825926)
# (get_point_vector pid=1825945)
# (get_point_vector pid=1825976)
# (get_neighbor_vectors pid=1825882)
# (get_point_vector pid=1825949)
# (get_median_vector pid=1825907)
# (get_point_vector pid=1825957)
# (select_point_in_dot_product_space pid=1827497)
# (get_point_vector pid=1825927)
# (get_point_vector pid=1825955)
# (get_point_vector pid=1825892)
# (get_point_vector pid=1825971)
# (get_neighbor_vectors pid=1825906)
# (get_point_vector pid=1825907)
# (select_point_in_dot_product_space pid=1825907)
# (get_neighbor_vectors pid=1825904)
# CPU times: user 19min 1s, sys: 2min 59s, total: 22min
# Wall time: 9min 24s
# (get_point_vector pid=1830652)
# (get_point_vector pid=1830653)
# (get_neighbor_vectors pid=1830457)
# (get_point_vector pid=1825969)
# (single_thread_align_vector_sign pid=1825909)
# (get_point_vector pid=1825923)
# (get_neighbor_vectors pid=1825948)
# (get_median_vector pid=1825916)
# (select_point_in_dot_product_space pid=1825987)
# (get_point_vector pid=1825842)
# (get_point_vector pid=1825912)
# (get_median_vector pid=1825880)
# (select_point_in_dot_product_space pid=1825896)
# (get_point_vector pid=1825900)
# (get_point_vector pid=1825943)
# (get_median_vector pid=1825945)
# (select_point_in_dot_product_space pid=1825894)
# (get_median_vector pid=1825899)
# (get_point_vector pid=1825842)
# (get_neighbor_vectors pid=1825946)
# (select_point_in_dot_product_space pid=1825972)
# (get_point_vector pid=1825896)
# (get_point_vector pid=1831299)
# (single_thread_align_vector_sign pid=1825842)
# (get_neighbor_vectors pid=1825971)
# (get_point_vector pid=1825980)
# (get_neighbor_vectors pid=1825929)
# (get_median_vector pid=1825895)
# (get_neighbor_vectors pid=1825952)
# (get pid=1825893) _point_vector
# (select_point_in_dot_product_space pid=1825964)
# (single_thread_align_vector_sign pid=1825949)
# (get_median_vector pid=1825943)
# (get_point_vector pid=1825972)
# (select_point_in_dot_product_space pid=1825929)
# (get_point_vector pid=1825955)
# (single_thread_align_vector_sign pid=1825904)
# (get_point_vector pid=1825916)
# (get_point_vector pid=1830258)
# (select_point_in_dot_product_space pid=1830950)
# (get_median_vector pid=1825957)
# (get_neighbor_vectors pid=1825909)
# (select_point_in_dot_product_space pid=1825987)
# (get_point_vector pid=1830258)
# (get_point_vector pid=1825916)
# (single_thread_align_vector_sign pid=1825907)
# (single_thread_align_vector_sign pid=1825976)
# (get_point_vector pid=1830386)
# (get_neighbor_vectors pid=1825912)
# (get_point_vector pid=1825907)
# (get_median_vector pid=1825897)
# (get_median_vector pid=1831255)
# (select_point_in_dot_product_space pid=1831472)
# (select_point_in_dot_product_space pid=1831359)
# (get_neighbor_vectors pid=1831472)
# (single_thread_align_vector_sign pid=1830652)
# (get_median_vector pid=1830887)
# (select_point_in_dot_product_space pid=1825889)
# (single_thread_align_vector_sign pid=1831525)
# (select_point_in_dot_product_space pid=1825904)
# (single_thread_align_vector_sign pid=1825962)
# (get_median_vector pid=1831420)
# (get_median_vector pid=1825911)
# (get_median_vector pid=1825976)
# (select_point_in_dot_product_space pid=1825980)
# (single_thread_align_vector_sign pid=1825890)
# (get_median_vector pid=1825882)
# (get_median_vector pid=1825914)
# (get_median_vector pid=1825916)
# (get_neighbor_vectors pid=1825951)
# (get_median_vector pid=1825897)
# (get_median_vector pid=1831420)
# (get_neighbor_vectors pid=1831389)
# (get_median_vector pid=1831299)
# (single_thread_align_vector_sign pid=1825926)
# (select_point_in_dot_product_space pid=1831780)
# (get_neighbor_vectors pid=1825982)
# (select_point_in_dot_product_space pid=1825889)
# (get_median_vector pid=1831992)
# (single_thread_align_vector_sign pid=1825882)
# (single_thread_align_vector_sign pid=1831389)
# (get_median_vector pid=1825987)
# (single_thread_align_vector_sign pid=1825906)
# (get_neighbor_vectors pid=1825907)
# (get_median_vector pid=1831699)
# (get_neighbor_vectors pid=1825911)
# (get_median_vector pid=1831653)
# (select_point_in_dot_product_space pid=1825916)
# (single_thread_align_vector_sign pid=1825894)
# (get_neighbor_vectors pid=1832139)
# (select_point_in_dot_product_space pid=1825907)
# (get_median_vector pid=1825971)
# (get_median_vector pid=1825842)
# (get_neighbor_vectors pid=1825904)
# (single_thread_align_vector_sign pid=1825964)
# (get_neighbor_vectors pid=1830796)
# (single_thread_align_vector_sign pid=1830887)
# (single_thread_align_vector_sign pid=1832139)
# (single_thread_align_vector_sign pid=1825940)
# (single_thread_align_vector_sign pid=1825907)
# (get_median_vector pid=1831723)
# (select_point_in_dot_product_space pid=1825923)
# (single_thread_align_vector_sign pid=1825978)
# (single_thread_align_vector_sign pid=1825962)
# (get_neighbor_vectors pid=1832165)
# (select_point_in_dot_product_space pid=1832428)
# (get_neighbor_vectors pid=1825969)
# (get_median_vector pid=1825893)
# (get_median_vector pid=1831420)
# (get_neighbor_vectors pid=1825951)
# (get_median_vector pid=1825889)
# (get_neighbor_vectors pid=1825980)
# (select_point_in_dot_product_space pid=1825914)
# (select_point_in_dot_product_space pid=1832671)
# (get_neighbor_vectors pid=1825904)
# (get_neighbor_vectors pid=1825906)
# (single_thread_align_vector_sign pid=1832116)
# (get_median_vector pid=1825948)
# (get_median_vector pid=1825971)
# (single_thread_align_vector_sign pid=1825969)
# (get_median_vector pid=1825940)
# (select_point_in_dot_product_space pid=1831780)
# (select_point_in_dot_product_space pid=1825945)
# (get_median_vector pid=1832671)
# (select_point_in_dot_product_space pid=1830887)
# (single_thread_align_vector_sign pid=1825890)
# (single_thread_align_vector_sign pid=1832460)
# (get_median_vector pid=1825933)
# (get_neighbor_vectors pid=1832720)
# (single_thread_align_vector_sign pid=1825980)
# (get_median_vector pid=1832116)
# (select_point_in_dot_product_space pid=1825964)
# (get_median_vector pid=1827497)
# (select_point_in_dot_product_space pid=1825994)
# (get_neighbor_vectors pid=1825971)
# (single_thread_align_vector_sign pid=1832842)
# (single_thread_align_vector_sign pid=1825943)
# (single_thread_align_vector_sign pid=1825890)
# (select_point_in_dot_product_space pid=1832842)
# (get_neighbor_vectors pid=1831327)
# (get_neighbor_vectors pid=1825880)
# (select_point_in_dot_product_space pid=1825895)
# (get_median_vector pid=1825889)
# (get_median_vector pid=1830796)
# (select_point_in_dot_product_space pid=1825933)
# (get_median_vector pid=1833122)
# (get_neighbor_vectors pid=1825943)
# (single_thread_align_vector_sign pid=1825911)
# (get_neighbor_vectors pid=1832295)
# (get_median_vector pid=1825893)
# (single_thread_align_vector_sign pid=1825924)
# (single_thread_align_vector_sign pid=1825894)
# (get_median_vector pid=1830887)
# (get_median_vector pid=1833365)
# (get_neighbor_vectors pid=1833003)
# (get_neighbor_vectors pid=1830887)
# (single_thread_align_vector_sign pid=1825933)
# (get_neighbor_vectors pid=1825952)
# (single_thread_align_vector_sign pid=1831699)
# (single_thread_align_vector_sign pid=1831525)
# (select_point_in_dot_product_space pid=1832139)
# (get_neighbor_vectors pid=1825987)
# (get_median_vector pid=1825916)
# (single_thread_align_vector_sign pid=1832815)
# (get_median_vector pid=1833003)
# (single_thread_align_vector_sign pid=1833122)
# (select_point_in_dot_product_space pid=1831699)
# (get_neighbor_vectors pid=1832268)
# (get_neighbor_vectors pid=1831653)
# (select_point_in_dot_product_space pid=1833319)
# (select_point_in_dot_product_space pid=1833197)
# (single_thread_align_vector_sign pid=1825994)
# (single_thread_align_vector_sign pid=1833197)
# (select_point_in_dot_product_space pid=1825978)
# (get_median_vector pid=1832139)
# (select_point_in_dot_product_space pid=1825904)
# (get_neighbor_vectors pid=1825978)
# (get_median_vector pid=1825924)
# (get_neighbor_vectors pid=1832116)
# (single_thread_align_vector_sign pid=1833392)
# (get_neighbor_vectors pid=1833318)
# (get_median_vector pid=1830950)
# (select_point_in_dot_product_space pid=1833197)
# (select_point_in_dot_product_space pid=1825933)
# (get_neighbor_vectors pid=1825951)
# (get_neighbor_vectors pid=1825890)
# (get_neighbor_vectors pid=1832116)
# (get_neighbor_vectors pid=1833294)
# (get_neighbor_vectors pid=1831525)
# (get_neighbor_vectors pid=1832295)
# (get_neighbor_vectors pid=1833003)
# (select_point_in_dot_product_space pid=1825842)
# (single_thread_align_vector_sign pid=1833169)
# (get_neighbor_vectors pid=1833197)
# (get_median_vector pid=1833659)
# (get_neighbor_vectors pid=1833762)
# (select_point_in_dot_product_space pid=1830950)
# (get_neighbor_vectors pid=1832671)
# (get_neighbor_vectors pid=1832842)
# (select_point_in_dot_product_space pid=1833762)
# (single_thread_align_vector_sign pid=1832165)
# (get_neighbor_vectors pid=1833096)
# (single_thread_align_vector_sign pid=1825951)
# (select_point_in_dot_product_space pid=1833813)
# (select_point_in_dot_product_space pid=1833318)
# (get_neighbor_vectors pid=1834033)
# (get_neighbor_vectors pid=1825969)
# (single_thread_align_vector_sign pid=1832815)
# (get_neighbor_vectors pid=1831723)
# (get_neighbor_vectors pid=1833197)
# (single_thread_align_vector_sign pid=1833222)
# (single_thread_align_vector_sign pid=1833997)
# (select_point_in_dot_product_space pid=1833916)
# (select_point_in_dot_product_space pid=1831420)
# (single_thread_align_vector_sign pid=1833692)
# (select_point_in_dot_product_space pid=1825890)
# (get_neighbor_vectors pid=1833096)
# (single_thread_align_vector_sign pid=1832370)
# (get_neighbor_vectors pid=1832842)
# (get_neighbor_vectors pid=1832116)
# (get_neighbor_vectors pid=1832165)
# (select_point_in_dot_product_space pid=1833997)
# (single_thread_align_vector_sign pid=1834033)
# (get_neighbor_vectors pid=1825987)
# (get_median_vector pid=1834033)
# (single_thread_align_vector_sign pid=1825951)
# (single_thread_align_vector_sign pid=1832842)
# (single_thread_align_vector_sign pid=1833997)
# (select_point_in_dot_product_space pid=1825951)
# (select_point_in_dot_product_space pid=1832890)
# (get_median_vector pid=1825987)
# (get_neighbor_vectors pid=1830887)
# (get_neighbor_vectors pid=1833294)
# (get_median_vector pid=1830887)
# (get_neighbor_vectors pid=1825894)
# (get_median_vector pid=1825951)
# (get_median_vector pid=1825987)
# (single_thread_align_vector_sign pid=1833659)
# (get_neighbor_vectors pid=1833319)
# (get_median_vector pid=1833319)
# (single_thread_align_vector_sign pid=1833365)
# (get_median_vector pid=1832842)
# (single_thread_align_vector_sign pid=1825994)
# (get_neighbor_vectors pid=1832139)
# (single_thread_align_vector_sign pid=1834033)
# (get_neighbor_vectors pid=1825890)
# (get_median_vector pid=1834621)
# (get_neighbor_vectors pid=1825890)
# (single_thread_align_vector_sign pid=1825923)
# (single_thread_align_vector_sign pid=1831420)
# (select_point_in_dot_product_space pid=1825957)
# (get_neighbor_vectors pid=1825890)
# (get_neighbor_vectors pid=1825895)
# (get_median_vector pid=1833294)
# (single_thread_align_vector_sign pid=1825899)
# (single_thread_align_vector_sign pid=1825890)
# (single_thread_align_vector_sign pid=1825962)
# (select_point_in_dot_product_space pid=1833222)
# (get_median_vector pid=1832720)
# (get_median_vector pid=1825916)
# (get_median_vector pid=1834263)
# (get_neighbor_vectors pid=1833813)
# (get_median_vector pid=1834621)
# (single_thread_align_vector_sign pid=1831255)
# (select_point_in_dot_product_space pid=1833997)
# (get_neighbor_vectors pid=1833222)
# (single_thread_align_vector_sign pid=1833813)
# (select_point_in_dot_product_space pid=1825894)
# (get_median_vector pid=1834443)
# (get_neighbor_vectors pid=1833003)
# (single_thread_align_vector_sign pid=1832295)
# (single_thread_align_vector_sign pid=1825895)
# (single_thread_align_vector_sign pid=1831255)
# (select_point_in_dot_product_space pid=1833600)
# (select_point_in_dot_product_space pid=1825916)
# (get_neighbor_vectors pid=1833222)
# (get_median_vector pid=1825890)
# (get_neighbor_vectors pid=1832890)
# (get_median_vector pid=1831992)
# (select_point_in_dot_product_space pid=1832268)
# (get_neighbor_vectors pid=1833294)
# (get_median_vector pid=1825899)
# (select_point_in_dot_product_space pid=1832842)
# (select_point_in_dot_product_space pid=1825842)
# (get_median_vector pid=1825890)
# (select_point_in_dot_product_space pid=1833365)
# (select_point_in_dot_product_space pid=1831992)
# (select_point_in_dot_product_space pid=1825916)
# (single_thread_align_vector_sign pid=1833294)
# (select_point_in_dot_product_space pid=1834895)
# (get_median_vector pid=1832890)
# (select_point_in_dot_product_space pid=1833600)
# (get_neighbor_vectors pid=1834896)
# (get_median_vector pid=1825969)
# (get_median_vector pid=1833318)
# (select_point_in_dot_product_space pid=1825904)
# (select_point_in_dot_product_space pid=1834443)
# (select_point_in_dot_product_space pid=1825916)
# (get_median_vector pid=1834950)
# (get_neighbor_vectors pid=1825893)
# (get_median_vector pid=1835088)
# (single_thread_align_vector_sign pid=1832295)
# (select_point_in_dot_product_space pid=1834896)
# (get_neighbor_vectors pid=1835327)
# (get_neighbor_vectors pid=1831992)
# (single_thread_align_vector_sign pid=1825890)
# (select_point_in_dot_product_space pid=1832165)
# (select_point_in_dot_product_space pid=1834816)
# (get_neighbor_vectors pid=1825994)
# (single_thread_align_vector_sign pid=1832460)
# (get_median_vector pid=1833692)
# (select_point_in_dot_product_space pid=1833692)
# (get_median_vector pid=1834842)
# (get_neighbor_vectors pid=1833692)
# (select_point_in_dot_product_space pid=1831723)
# (select_point_in_dot_product_space pid=1825895)
# (single_thread_align_vector_sign pid=1825948)
# (select_point_in_dot_product_space pid=1835752)
# (single_thread_align_vector_sign pid=1834896)
# (select_point_in_dot_product_space pid=1825899)
# (single_thread_align_vector_sign pid=1831255)
# (get_median_vector pid=1833096)
# (get_neighbor_vectors pid=1833365)
# (select_point_in_dot_product_space pid=1832295)
# (get_neighbor_vectors pid=1834790)
# (get_median_vector pid=1825894)
# (select_point_in_dot_product_space pid=1825994)
# (get_median_vector pid=1831723)
# (single_thread_align_vector_sign pid=1833318)
# (get_median_vector pid=1825894)
# (get_median_vector pid=1836147)
# (get_median_vector pid=1825969)
# (get_median_vector pid=1832116)
# (get_neighbor_vectors pid=1825994)
# (single_thread_align_vector_sign pid=1833222)
# (get_median_vector pid=1835060)
# (get_median_vector pid=1831420)
# (get_median_vector pid=1825899)
# (single_thread_align_vector_sign pid=1836270)
# (single_thread_align_vector_sign pid=1834816)
# (select_point_in_dot_product_space pid=1835806)
# (get_neighbor_vectors pid=1833197)
# (select_point_in_dot_product_space pid=1825987)
# (single_thread_align_vector_sign pid=1825895)
# (get_median_vector pid=1833294)
# (single_thread_align_vector_sign pid=1833392)
# (get_median_vector pid=1830887)
# (select_point_in_dot_product_space pid=1836270)
# (get_median_vector pid=1832890)
# (single_thread_align_vector_sign pid=1825962)
# (single_thread_align_vector_sign pid=1836448)
# (select_point_in_dot_product_space pid=1825895)
# (select_point_in_dot_product_space pid=1825899)
# (single_thread_align_vector_sign pid=1833392)
# (get_median_vector pid=1825969)
# (get_median_vector pid=1825895)
# (select_point_in_dot_product_space pid=1833197)
# (select_point_in_dot_product_space pid=1832165)
# (single_thread_align_vector_sign pid=1834753)
# (get_median_vector pid=1834790)
# (get_median_vector pid=1834896)
# (select_point_in_dot_product_space pid=1836328)
# (get_median_vector pid=1825994)
# (select_point_in_dot_product_space pid=1834895)
# (get_neighbor_vectors pid=1835088)
# (single_thread_align_vector_sign pid=1833392)
# (get_median_vector pid=1836472)
# (single_thread_align_vector_sign pid=1830887)
# (single_thread_align_vector_sign pid=1835577)
# (get_neighbor_vectors pid=1834033)
# (get_median_vector pid=1825890)
# (single_thread_align_vector_sign pid=1835327)
# (get_neighbor_vectors pid=1836214)
# (get_neighbor_vectors pid=1836472)
# (select_point_in_dot_product_space pid=1833318)
# (select_point_in_dot_product_space pid=1833692)
# (select_point_in_dot_product_space pid=1834816)
# (single_thread_align_vector_sign pid=1836472)
# (single_thread_align_vector_sign pid=1833319)
# (get_neighbor_vectors pid=1835088)
# (single_thread_align_vector_sign pid=1835135)
# (get_median_vector pid=1834950)

# %%
keeping = ray.get(keeping)
extract_idx = np.where(mask_1d)[0][keeping]

# %%
# if False: # True to save images and variables for later use.
#     vec_img = np.zeros(shape+(dim,)).astype(np.float32)
#     extracted = points_position_array[keeping]
#     vec_img[tuple(extracted.T)] = point_vectors[keeping,:]
    
#     # export extracted vetors as image
#     tifffile.imwrite(os.path.join(io_directory,'local_vector.tif'),
#                  np.moveaxis(vec_img,-1,1).astype(np.float32),
#                  imagej=True,
#                  metadata={'spacing': 12, 'unit': 'um', 'axes': 'ZCYX'})
    
#     # save variables as .npy
#     np.save(os.path.join(io_directory,'extract_idx.npy'), extract_idx)
#     np.save(os.path.join(io_directory,'point_vectors.npy'), point_vectors)
#     np.save(os.path.join(io_directory,'keeping.npy'), np.asarray(keeping))

# %%
# Fit to the nth polynomial
degree = 5
idx = np.array(np.unravel_index(extract_idx,shape)).T
vec = point_vectors[keeping,:]
poly = PolynomialFeatures(degree=degree) # Overfitting may happen at the edge?
idx_ = poly.fit_transform(idx)

clf = linear_model.LinearRegression(fit_intercept=False) # False
clf.fit(idx_,vec)# Fit the model
clf.degree = degree# save information for polynomial degree for later use

# %%
# filename = '/mnt/ampa_data01/tmurakami/220305_SMA_nuc_middlehuman/vessel_analysis/model.pkl'
pickle.dump(clf, open(os.path.join(io_directory,'model.pkl'), 'wb'))

# %%
ray.shutdown()

# %%
# # Export the vector field as image if it is required.
# if False: # honestly, the interpretation is difficult and does not help much.
#     all_coord = np.indices(shape)
#     all_coord = np.stack([all_coord[i,:,:,:].flatten() for i in range(dim)], axis=1).astype(int)
#     all_coord_ = poly.fit_transform(all_coord)

#     fit_img = clf.predict(all_coord_)
#     fit_img = fit_img.reshape(shape+(dim,))
#     vector_field_tif = os.path.join(io_directory,'vector_field_interpolation.tif')

#     # export extracted vetors as image
#     tifffile.imwrite(vector_field_tif,
#              np.moveaxis(fit_img,-1,1).astype(np.float32),
#              imagej=True,
#              metadata={'spacing': 10, 'unit': 'um', 'axes': 'ZCYX'})
#     del(all_coord)
#     del(all_coord_)
#     del(fit_img)

# %%
np.asarray(keeping).sum()
# Out:
# 792712

# %%
#
